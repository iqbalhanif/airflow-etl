# %% [markdown]
# # Load & Install Package

# %%
## Install package
##!pip install pymysql
##!pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.1.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.

# %%
##load package
from sqlalchemy import create_engine
import pandas as pd
import pymysql

# %% [markdown]
# # Extract from PostgreSQL
#
# Table List:
# - Album
# - Artist
# - Customer
# - Employee
# - Genre
# - Invoice
# - InvoiceLine
# - MediaType
# - Playlist
# - PlaylistTrack
# - Track

# %%
## create postgresql_engine
engine1 = create_engine('postgresql://postgres:abcd1234@127.0.0.1:5432/postgres')

# %%
## extract tables from potgresql
df_album        =pd.read_sql_query('select * from postgres.public."Album";',con=engine1)
df_artist       =pd.read_sql_query('select * from postgres.public."Artist";',con=engine1)
df_customer     =pd.read_sql_query('select * from postgres.public."Customer";',con=engine1)
df_employee     =pd.read_sql_query('select * from postgres.public."Employee";',con=engine1)
df_genre        =pd.read_sql_query('select * from postgres.public."Genre";',con=engine1)
df_invoice      =pd.read_sql_query('select * from postgres.public."Invoice";',con=engine1)
df_invoiceline  =pd.read_sql_query('select * from postgres.public."InvoiceLine";',con=engine1)
df_mediatype    =pd.read_sql_query('select * from postgres.public."MediaType";',con=engine1)
df_playlist     =pd.read_sql_query('select * from postgres.public."Playlist";',con=engine1)
df_playlisttrack=pd.read_sql_query('select * from postgres.public."PlaylistTrack";',con=engine1)
df_track        =pd.read_sql_query('select * from postgres.public."Track";',con=engine1)

# %%
## checking ectracted table
## df_track
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %% [markdown]
# # Load to MySQL
#
# Load all datafarames into these tables:
# - album2
# - artist2
# - customer2
# - employee2
# - genre2
# - invoice2
# - invoiceline2
# - mediatype2
# - playlist2
# - playlisttrack2
# - track2

# %%
## creaate mysql_engine
engine2 = create_engine('mysql+pymysql://root:abcd1234@127.0.0.1:3306/hr')

# %%
df_album.to_sql("album2", con=engine2, if_exists="replace", index=False)
df_artist.to_sql("artist2", con=engine2, if_exists="replace", index=False)
df_customer.to_sql("customer2", con=engine2, if_exists="replace", index=False)
df_employee.to_sql("employee2", con=engine2, if_exists="replace", index=False)
df_genre.to_sql("genre2", con=engine2, if_exists="replace", index=False)
df_invoice.to_sql("invoice2", con=engine2, if_exists="replace", index=False)
df_invoiceline.to_sql("invoiceline2", con=engine2, if_exists="replace", index=False)
df_mediatype.to_sql("mediatype2", con=engine2, if_exists="replace", index=False)
df_playlist.to_sql("playlist2", con=engine2, if_exists="replace", index=False)
df_playlisttrack.to_sql("playlisttrack2", con=engine2, if_exists="replace", index=False)
df_track.to_sql("track2", con=engine2, if_exists="replace", index=False)

# %%
## checking loaded table
## pd.read_sql_query('select * from hr.album2;',con=engine2)
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %% [markdown]
# # Convert into Callable Python Function

# %%
def callable_python():
    from sqlalchemy import create_engine
    import pandas as pd
    import pymysql

    ## create postgresql_engine & mysql_engine
    engine1 = create_engine('postgresql://postgres:abcd1234@127.0.0.1:5432/postgres')
    engine2 = create_engine('mysql+pymysql://root:abcd1234@127.0.0.1:3306/hr')

    def etl_function(table_name):
        ##extract_table
        sql_query1 = 'select * from postgres.public."%s";'%(table_name)
        df=pd.read_sql_query(sql_query1,con=engine1)

        ##load_table
        new_table = str.lower(table_name) + '2'
        df.to_sql(new_table, con=engine2, if_exists="replace", index=False)

    table_name = [
    'Album'
    ,'Artist'
    ,'Customer'
    ,'Employee'
    ,'Genre'
    ,'Invoice'
    ,'InvoiceLine'
    ,'MediaType'
    ,'Playlist'
    ,'PlaylistTrack'
    ,'Track']
        
    for i in table_name:
        etl_function(i)
        print('Finished extracting %s'%(i), end='\n')
